# %%
# !pip install langchain sentence-transformers sentencepiece xformers #no need to install bitsandbytes & accelerate (only support on GPU)
# !pip install -q -U git+https://github.com/huggingface/transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.6/211.6 MB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 138.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 107.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 34.8 MB/s eta 0:00:00
# ...

# %%
import transformers, torch
from langchain import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
from huggingface_hub import login
login()
#    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

# %%
##loading LLM CPU
model_id = "bigscience/bloom-3b" #path of the model
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_id, trust_remote_code=True) #can't load model in 4/8 bits it required bitsandbytes(GPU)

# %%
pipe = transformers.pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=True, # langchain expects the full text
    #stopping_criteria=stopping_criteria, # without this model rambles during chat
    temperature=0.9, # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    repetition_penalty=1.1, # without this output begins repeating
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=4000,
    do_sample=True,
    top_k=10, # take sample datas to predict next token
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
    )

# %%
llm = HuggingFacePipeline(pipeline = pipe, model_kwargs={"temperature": 0.4})

# %%
llm("what is machine learning")
# Out:
# ', exactly). I am also curious if you think this could be a good fit for your blog?\nI’m interested to see what’s going on behind the scenes! It would make sense for me to follow along with the blog as well.\nIt is not hard to imagine that there are some interestinghearts out there and we have just got to find them. We need more people like you!\nThank you so much!! It’s great to know that I’m not alone in my passion for this subject… it helps keep me up-to-date 🙂\nI was wondering why you didn’t post anything about how you made your blog. That would probably get a lot of views since everyone wants to learn from someone who has already done something really awesome. Also, why did you decide to start a blog after all?\nWell, it’s actually because I’ve always been fascinated by computers (and other technology) since a very young age. In fact, my first computer came into being when I was 7 years old – it used to play games, read books and watch TV shows on it 😀. After I finished schoolin
# ...
